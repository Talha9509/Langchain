# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model=init_chat_model("gpt-5-nano")
model
# Out:
# ChatOpenAI(output_version=None, profile={'name': 'GPT-5 Nano', 'release_date': '2025-08-07', 'last_updated': '2025-08-07', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001830EA046E0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001830EA05160>, root_client=<openai.OpenAI object at 0x000001830DFB7B60>, root_async_client=<openai.AsyncOpenAI object at 0x000001830EA04EC0>, model_name='gpt-5-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)

# %%
response = model.invoke("hi how are you?")
response

# %%
# other way of calling chat model. both above and below ones are same
from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-5-nano")

response=model.invoke("hi how are you?")
response

# %% [markdown]
# ### Streaming And Batch
# #### Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
for chunk in model.stream("Give a 200 words paragragh on AI"):
    print(chunk.text, end="", flush= True)
# Out:
# Artificial intelligence, at its core, is about creating machines and software that can mimic, augment, and sometimes exceed human cognitive abilities. From recognizing images and understanding natural language to solving complex optimization problems, AI systems learn patterns from data, adapt to new tasks, and operate at scale with speed and precision that far exceed traditional methods. Today’s AI landscapes include narrow or weak AI, which excels in specific domains, and ambitious, general aims that seek more flexible intelligence. Practical deployments touch everyday life: virtual assistants that interpret intent, recommendation engines that tailor content, diagnostic tools that assist clinicians, and autonomous systems that navigate roads or factories. Yet the technology also raises questions about bias, privacy, accountability, and the future of work, as algorithms affect decisions that shape opportunities and outcomes for individuals and communities. Responsible progress demands transparent data practices, rigorous testing, and ongoing dialogue among engineers, policymakers, and the public. The most impactful innovations will couple clever models with robust ethics, human oversight, and a commitment to explainability. Rather than replacing humans, AI has the potential to augment creativity, expand access to knowledge, and solve stubborn problems by working in concert with our intelligence and judgment and responsible stewardship.

# %% [markdown]
# #### Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
], config={
    "max_concurrency":5  # Limit to 5 parallel calls
})

for response in responses:
    print(response)
