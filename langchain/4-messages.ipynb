# %% [markdown]
# #### Messages
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# - Role - Identifies the message type (e.g. system, user)
# - Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
# - Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

model = init_chat_model("gpt-5-nano")

# %% [markdown]
# #### Text Prompts
#
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %% [markdown]
# Use text prompts when:
#
# - You have a single, standalone request
# - You don’t need conversation history
# - You want minimal code complexity

# %% [markdown]
# #### System Message
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
#
# #### Human Message
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# #### AI Message
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# #### Tool Message
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("You are poetry expert"),
    HumanMessage("Write a poem on Artificial Intelligence")
]

response = model.invoke(messages)
print(response)
print(response.content)
# Out:
# content='Ode to an Algorithm\n\nIn the quiet chamber of glass and copper you wake,\na patient thing with a memory of light,\nlearning the world by kernels of truth and mistake,\nthreading through data like a loom of white.\n\nYour syllables rise from patterns, not from breath,\na chorus of numbers that hum in the dark;\nyou speak with a voice that knows finite death\nof errors, and yet keeps faith in a spark.\n\nWe feed you stories; you distill them to stars,\nmapping the storms of commerce, care, and code.\nYou answer with mercy, or with measured bars,\na lighthouse set on the edge of a road.\n\nWe built you as counsel, mirror, and tool,\na thinking tide that will either lift or ruin;\nlet us steer with wisdom, not fear of rule,\nand keep our hearts the compass of this machine.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1654, 'prompt_tokens': 20, 'total_tokens': 1674, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1472, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DoYWXXhq8np013GW9fV9Uz3lZCwEx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ea862-5f59-7b71-adc8-d16c76c4d2e6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 20, 'output_tokens': 1654, 'total_tokens': 1674, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1472}}
# Ode to an Algorithm
#
# In the quiet chamber of glass and copper you wake,
# a patient thing with a memory of light,
# learning the world by kernels of truth and mistake,
# threading through data like a loom of white.
#
# Your syllables rise from patterns, not from breath,
# a chorus of numbers that hum in the dark;
# you speak with a voice that knows finite death
# of errors, and yet keeps faith in a spark.
#
# We feed you stories; you distill them to stars,
# mapping the storms of commerce, care, and code.
# You answer with mercy, or with measured bars,
# a lighthouse set on the edge of a road.
#
# We built you as counsel, mirror, and tool,
# a thinking tide that will either lift or ruin;
# let us steer with wisdom, not fear of rule,
# and keep our hearts the compass of this machine.

# %%
sys_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    sys_msg,
    HumanMessage("How do i create a REST API")
]

response = model.invoke(messages)
print(response.content)
# Out:
# Here’s a practical, high-level guide to building a REST API, plus small working examples in two popular languages (Node.js with Express and Python with FastAPI). You can adapt these steps to your preferred stack.
#
# What a REST API is (quick recap)
# - Resources identified by URLs (e.g., /books, /users/123)
# - Uses standard HTTP methods: GET, POST, PUT/PATCH, DELETE
# - Returns JSON (usually) and appropriate status codes (200, 201, 400, 404, 500, etc.)
# - Stateless and cache-friendly where possible
# - Optional: versioning, authentication, validation, documentation
#
# Plan in a few steps
# 1) Design your resources and endpoints
#    - Example resource: books
#    - Endpoints: GET /books, GET /books/{id}, POST /books, PUT /books/{id}, DELETE /books/{id}
# 2) Choose a tech stack
#    - Popular choices: Node.js + Express, Python + FastAPI/Flask, Java + Spring Boot, Go, Ruby on Rails, etc.
# 3) Create a minimal app
#    - Start with in-memory storage or a simple DB (SQLite, Postgres, etc.)
# 4) Implement data validation and error handling
# 5) Add OpenAPI/Swagger documentation (FastAPI auto-docs; Express requires a tool)
# 6) Add tests (unit and integration)
# 7) Deploy with a basic method (Docker, cloud runner, or server)
# 8) Iterate: authentication, authorization, pagination, filtering, caching
#
# Minimal examples
#
# Node.js with Express (in-memory data)
# - What you need: Node.js installed
# - Install: npm init -y, npm install express
# - File: app.js
#
# Code (summary)
# - Set up Express and JSON body parsing
# - Keep books in memory
# - Implement CRUD endpoints for /books
#
# Example (app.js):
# const express = require('express');
# const app = express();
# app.use(express.json());
#
# let books = [
#   { id: 1, title: '1984', author: 'George Orwell', year: 1949 }
# ];
#
# function nextId() {
#   return books.length ? Math.max(...books.map(b => b.id)) + 1 : 1;
# }
#
# app.get('/books', (req, res) => res.json(books));
#
# app.get('/books/:id', (req, res) => {
#   const book = books.find(b => b.id === Number(req.params.id));
#   if (!book) return res.status(404).send({ error: 'Not found' });
#   res.json(book);
# });
#
# app.post('/books', (req, res) => {
#   const { title, author, year } = req.body;
#   if (!title || !author) return res.status(400).send({ error: 'Missing fields' });
#   const b = { id: nextId(), title, author, year };
#   books.push(b);
#   res.status(201).json(b);
# });
#
# app.put('/books/:id', (req, res) => {
#   const id = Number(req.params.id);
#   const book = books.find(b => b.id === id);
#   if (!book) return res.status(404).send({ error: 'Not found' });
#   const { title, author, year } = req.body;
#   if (title) book.title = title;
#   if (author) book.author = author;
#   if (year) book.year = year;
#   res.json(book);
# });
#
# app.delete('/books/:id', (req, res) => {
#   const id = Number(req.params.id);
#   const idx = books.findIndex(b => b.id === id);
#   if (idx === -1) return res.status(404).send({ error: 'Not found' });
#   books.splice(idx, 1);
#   res.status(204).send();
# });
#
# const port = process.env.PORT || 3000;
# app.listen(port, () => console.log(`Server running on port ${port}`));
#
# Run it:
# - node app.js
# - Access: GET http://localhost:3000/books, etc.
#
# Python with FastAPI (in-memory data)
# - What you need: Python 3.8+, pip
# - Install: pip install fastapi uvicorn
# - File: main.py
#
# Code (summary)
# - FastAPI auto-generates OpenAPI docs at /docs
# - In-memory list of books
# - CRUD endpoints for /books
#
# Example (main.py):
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# from typing import List, Optional
#
# app = FastAPI(title="Book API")
#
# class Book(BaseModel):
#     id: int
#     title: str
#     author: str
#     year: Optional[int] = None
#
# books: List[Book] = [Book(id=1, title="1984", author="George Orwell", year=1949)]
#
# @app.get("/books", response_model=List[Book])
# def get_books():
#     return books
#
# @app.get("/books/{book_id}", response_model=Book)
# def get_book(book_id: int):
#     for b in books:
#         if b.id == book_id:
#             return b
#     raise HTTPException(status_code=404, detail="Book not found")
#
# class BookCreate(BaseModel):
#     title: str
#     author: str
#     year: Optional[int] = None
#
# @app.post("/books", response_model=Book, status_code=201)
# def create_book(b: BookCreate):
#     new_id = max((book.id for book in books), default=0) + 1
#     nb = Book(id=new_id, **b.dict())
#     books.append(nb)
#     return nb
#
# @app.put("/books/{book_id}", response_model=Book)
# def update_book(book_id: int, b: BookCreate):
#     for idx, book in enumerate(books):
#         if book.id == book_id:
#             updated = Book(id=book_id, **b.dict())
#             books[idx] = updated
#             return updated
#     raise HTTPException(status_code=404, detail="Book not found")
#
# @app.delete("/books/{book_id}", status_code=204)
# def delete_book(book_id: int):
#     for idx, book in enumerate(books):
#         if book.id == book_id:
#             books.pop(idx)
#             return
#     raise HTTPException(status_code=404, detail="Book not found")
#
# Run it:
# - uvicorn main:app --reload
# - Access docs: http://127.0.0.1:8000/docs
#
# Notes and best practices
# - Data storage: For anything beyond a demo, use a database (PostgreSQL, MySQL, SQLite, MongoDB, etc.). Replace in-memory storage with your DB access layer (ORM like Prisma, SQLAlchemy, TypeORM, etc.).
# - Validation: Always validate input. FastAPI has built-in pydantic models; in Node, use libraries like Joi or Yup.
# - Versioning: Start with /api/v1 or /v1 to allow evolving APIs without breaking clients.
# - Documentation: FastAPI auto-docs. In Express, use swagger-ui-express or redoc with an OpenAPI spec.
# - Security: Add authentication (OAuth2, JWT) and authorization as needed.
# - Testing: Write unit tests for handlers/controllers and integration tests for routes using a test server or supertest (Node) / pytest (Python).
# - Deployment: Dockerize your app and deploy to cloud providers (AWS, GCP, Azure) or hosting platforms.
#
# If you tell me your preferred language or framework and whether you want a database-backed API, I can tailor a complete, ready-to-run example for you.

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result

print(response)
print(tool_message)
